# %%
import os
import pandas as pd
import django

os.environ.setdefault("DJANGO_SETTINGS_MODULE", "sharathapp.settings")
django.setup()
# Out:
# Local!!

# %%
from io import BytesIO
from django.http import HttpResponse
from django.template.loader import get_template
import xhtml2pdf.pisa as pisa

# %%
get_template('resume_builder/template1.html')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\users\shara\envs\my-app\lib\site-packages\django\template\smartif.py in translate_token(self, token)
#     174         try:
# --> 175             op = OPERATORS[token]
#     176         except (KeyError, TypeError):
#
# KeyError: 'resume.skill_set.all()'
#
# During handling of the above exception, another exception occurred:
#
# TemplateSyntaxError                       Traceback (most recent call last)
# <ipython-input-3-83856ca4548b> in <module>
# ----> 1 get_template('resume_builder/template1.html')
#
# c:\users\shara\envs\my-app\lib\site-packages\django\template\loader.py in get_template(template_name, using)
#      19     for engine in engines:
#      20         try:
# ---> 21             return engine.get_template(template_name)
#      22         except TemplateDoesNotExist as e:
#      23             chain.append(e)
#
# c:\users\shara\envs\my-app\lib\site-packages\django\template\backends\django.py in get_template(self, template_name)
#      37     def get_template(self, template_name):
#      38         try:
# ---> 39             return Template(self.engine.get_template(template_name), self)
#      40         except TemplateDoesNotExist as exc:
#      41             reraise(exc, self)
#
# c:\users\shara\envs\my-app\lib\site-packages\django\template\engine.py in get_template(self, template_name)
#     160         handling template inheritance recursively.
#     161         """
# --> 162         template, origin = self.find_template(template_name)
#     163         if not hasattr(template, 'render'):
#     164             # template needs to be compiled
#
# c:\users\shara\envs\my-app\lib\site-packages\django\template\engine.py in find_template(self, name, dirs, skip)
#     134                 try:
#     135                     template = loader.get_template(
# --> 136                         name, template_dirs=dirs, skip=skip,
#     137                     )
#     138                     return template, template.origin
#
# c:\users\shara\envs\my-app\lib\site-packages\django\template\loaders\base.py in get_template(self, template_name, template_dirs, skip)
#      42             else:
#      43                 return Template(
# ---> 44                     contents, origin, origin.template_name, self.engine,
#      45                 )
#      46
#
# c:\users\shara\envs\my-app\lib\site-packages\django\template\base.py in __init__(self, template_string, origin, name, engine)
#     189         self.engine = engine
#     190         self.source = template_string
# --> 191         self.nodelist = self.compile_nodelist()
#     192
#     193     def __iter__(self):
#
# c:\users\shara\envs\my-app\lib\site-packages\django\template\base.py in compile_nodelist(self)
#     228
#     229         try:
# --> 230             return parser.parse()
#     231         except Exception as e:
#     232             if self.engine.debug:
#
# c:\users\shara\envs\my-app\lib\site-packages\django\template\base.py in parse(self, parse_until)
#     513                     compiled_result = compile_func(self, token)
#     514                 except Exception as e:
# --> 515                     raise self.error(token, e)
#     516                 self.extend_nodelist(nodelist, compiled_result, token)
#     517                 # Compile success. Remove the token from the command stack.
#
# c:\users\shara\envs\my-app\lib\site-packages\django\template\base.py in parse(self, parse_until)
#     511                 # the node list.
#     512                 try:
# --> 513                     compiled_result = compile_func(self, token)
#     514                 except Exception as e:
#     515                     raise self.error(token, e)
#
# c:\users\shara\envs\my-app\lib\site-packages\django\template\defaulttags.py in do_if(parser, token)
#     966     # {% if ... %}
#     967     bits = token.split_contents()[1:]
# --> 968     condition = TemplateIfParser(parser, bits).parse()
#     969     nodelist = parser.parse(('elif', 'else', 'endif'))
#     970     conditions_nodelists = [(condition, nodelist)]
#
# c:\users\shara\envs\my-app\lib\site-packages\django\template\defaulttags.py in __init__(self, parser, *args, **kwargs)
#     898     def __init__(self, parser, *args, **kwargs):
#     899         self.template_parser = parser
# --> 900         super(TemplateIfParser, self).__init__(*args, **kwargs)
#     901
#     902     def create_var(self, value):
#
# c:\users\shara\envs\my-app\lib\site-packages\django\template\smartif.py in __init__(self, tokens)
#     164                 token = "not in"
#     165                 i += 1  # skip 'in'
# --> 166             mapped_tokens.append(self.translate_token(token))
#     167             i += 1
#     168
#
# c:\users\shara\envs\my-app\lib\site-packages\django\template\smartif.py in translate_token(self, token)
#     175             op = OPERATORS[token]
#     176         except (KeyError, TypeError):
# --> 177             return self.create_var(token)
#     178         else:
#     179             return op()
#
# c:\users\shara\envs\my-app\lib\site-packages\django\template\defaulttags.py in create_var(self, value)
#     901
#     902     def create_var(self, value):
# --> 903         return TemplateLiteral(self.template_parser.compile_filter(value), value)
#     904
#     905
#
# c:\users\shara\envs\my-app\lib\site-packages\django\template\base.py in compile_filter(self, token)
#     598         Convenient wrapper for FilterExpression
#     599         """
# --> 600         return FilterExpression(token, self)
#     601
#     602     def find_filter(self, filter_name):
#
# c:\users\shara\envs\my-app\lib\site-packages\django\template\base.py in __init__(self, token, parser)
#     698         if upto != len(token):
#     699             raise TemplateSyntaxError("Could not parse the remainder: '%s' "
# --> 700                                       "from '%s'" % (token[upto:], token))
#     701
#     702         self.filters = filters
#
# TemplateSyntaxError: Could not parse the remainder: '()' from 'resume.skill_set.all()'
